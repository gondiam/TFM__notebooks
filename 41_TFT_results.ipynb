# %%
import pandas as pd
results_df = pd.read_csv('tft_return_evaluation_results.csv')
results_df.head()
# Out:
#   Ticker  Accuracy  Precision    Recall  F1-Score      RMSE
# 0   FANG  0.465587   0.463415  0.463415  0.463415  0.141178
# 1    BKR  0.522088   0.508772  0.479339  0.493617  0.020343
# 2   CDNS  0.626506   0.622951  0.617886  0.620408  0.029268
# 3   CSCO  0.530120   0.515625  0.545455  0.530120  0.013221
# 4   MSTR  0.433735   0.396396  0.372881  0.384279  0.073538

# %%
# Round the results_df.describe in 6 digits
results_df.describe().round(6)
# Out:
#          Accuracy   Precision      Recall    F1-Score        RMSE
# count  100.000000  100.000000  100.000000  100.000000  100.000000
# mean     0.537588    0.536782    0.534166    0.534810    0.030420
# std      0.075881    0.084781    0.075983    0.077892    0.018138
# min      0.349398    0.343137    0.289256    0.313901    0.010317
# 25%      0.477912    0.475308    0.483468    0.481633    0.018910
# 50%      0.528112    0.518017    0.536888    0.529060    0.025292
# 75%      0.587349    0.594682    0.589970    0.589147    0.037534
# max      0.702811    0.754545    0.682540    0.692607    0.141178

# %%
import plotly.express as px

# Suppose your dataframe is called results_df
# Reshape to long format
df_long = pd.melt(results_df, id_vars='Ticker',
                  value_vars=['Accuracy', 'Precision', 'Recall', 'F1-Score'],
                  var_name='Metric', value_name='Value')

# Create violin plot with boxplot and scatter points
fig = px.violin(df_long,
                x='Metric',
                y='Value',
                box=True,          # Add boxplot inside violin
                points='all',      # Show all data points
                color='Metric',    # Different color per metric
                hover_data=['Ticker'])

fig.update_layout(title='Distribution of Classification Metrics across Tickers',
                  yaxis_title='Value',
                  xaxis_title='Metric',
                  legend_title='Metric',
                  width=900,
                  height=500)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3f3f9c4d-1d8c-4f2f-8b93-c6c9fca62ce2" class="plotly-graph-div" style="height:500px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3f3f9c4d-1d8c-4f2f-8b93-c6c9fca62ce2")) {                    Plotly.newPlot(                        "3f3f9c4d-1d8c-4f2f-8b93-c6c9fca62ce2",                        [{"alignmentgroup":"True","box":{"visible":true},"customdata":[["FANG"],["BKR"],["CDNS"],["CSCO"],["MSTR"],["GOOG"],["FTNT"],["NVDA"],["TTD"],["GOOGL"],["ODFL"],["ADP"],["MCHP"],["XEL"],["ABNB"],["ADI"],["APP"],["BIIB"],["LIN"],["ORLY"],["REGN"],["AVGO"],["INTC"],["SBUX"],["PDD"],["AMZN"],["HON"],["MRVL"],["PYPL"],["MSFT"],["CHTR"],["LRCX"],["GILD"],["KDP"],["QCOM"],["GEHC"],["CMCSA"],["ANSS"],["AAPL"],["EA"],["MNST"],["WDAY"],["IDXX"],["TEAM"],["SNPS"],["VRSK"],["AMD"],["CTSH"],["AMAT"],["AXON"],["NFLX"],["DXCM"],["CSGP"],["TSLA"],["DASH"],["CDW"],["BKNG"],["MDLZ"],["CCEP"],["CEG"],["FAST"],["NXPI"],["VRTX"],["PEP"],["CTAS"],["META"],["MAR"],["SHOP"],["MU"],["ADBE"],["PANW"],["ON"],["ROST"],["MELI"],["WBD"],["PAYX"],["KLAC"],["CSX"],["KHC"],["LULU"],["CRWD"],["AZN"],["TXN"],["TTWO"],["ROP"],["ZS"],["GFS"],["ISRG"],["PLTR"],["ADSK"],["CPRT"],["AMGN"],["EXC"],["DDOG"],["AEP"],["PCAR"],["TMUS"],["COST"],["INTU"],["ASML"]],"hovertemplate":"Metric=%{x}\u003cbr\u003eValue=%{y}\u003cbr\u003eTicker=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Accuracy","marker":{"color":"#636efa"},"name":"Accuracy","offsetgroup":"Accuracy","orientation":"v","points":"all","scalegroup":"True","showlegend":true,"x":["Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy"],"x0":" ","xaxis":"x","y":[0.4655870445344129,0.5220883534136547,0.6265060240963856,0.5301204819277109,0.4337349397590361,0.5100401606425703,0.5261044176706827,0.570281124497992,0.6184738955823293,0.6827309236947792,0.4618473895582329,0.5542168674698795,0.5301204819277109,0.4738955823293173,0.5542168674698795,0.5863453815261044,0.4979919678714859,0.606425702811245,0.5220883534136547,0.5140562248995983,0.570281124497992,0.5742971887550201,0.6184738955823293,0.6305220883534136,0.5903614457831325,0.4578313253012048,0.6265060240963856,0.5140562248995983,0.5341365461847389,0.5140562248995983,0.4578313253012048,0.5983935742971888,0.5502008032128514,0.6706827309236948,0.6746987951807228,0.5140562248995983,0.4899598393574297,0.5020080321285141,0.4538152610441767,0.678714859437751,0.5261044176706827,0.5140562248995983,0.5341365461847389,0.3694779116465863,0.5301204819277109,0.4257028112449799,0.465863453815261,0.6184738955823293,0.6947791164658634,0.5140562248995983,0.4779116465863454,0.4538152610441767,0.6305220883534136,0.606425702811245,0.5341365461847389,0.5542168674698795,0.57831325301 ...

# %%
df_long = pd.melt(results_df, id_vars='Ticker',
                  value_vars=['RMSE'],
                  var_name='Metric', value_name='Value')

# Create violin plot with boxplot and scatter points
fig = px.violin(df_long,
                x='Metric',
                y='Value',
                box=True,          # Add boxplot inside violin
                points='all',      # Show all data points
                color='Metric',    # Different color per metric
                hover_data=['Ticker'])

fig.update_layout(title='Distribution of Regression Metric across Tickers',
                  yaxis_title='Value',
                  xaxis_title='Metric',
                  legend_title='Metric',
                  width=900,
                  height=500)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a747c0e0-20fc-41f8-816b-6552f834ae3c" class="plotly-graph-div" style="height:500px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a747c0e0-20fc-41f8-816b-6552f834ae3c")) {                    Plotly.newPlot(                        "a747c0e0-20fc-41f8-816b-6552f834ae3c",                        [{"alignmentgroup":"True","box":{"visible":true},"customdata":[["FANG"],["BKR"],["CDNS"],["CSCO"],["MSTR"],["GOOG"],["FTNT"],["NVDA"],["TTD"],["GOOGL"],["ODFL"],["ADP"],["MCHP"],["XEL"],["ABNB"],["ADI"],["APP"],["BIIB"],["LIN"],["ORLY"],["REGN"],["AVGO"],["INTC"],["SBUX"],["PDD"],["AMZN"],["HON"],["MRVL"],["PYPL"],["MSFT"],["CHTR"],["LRCX"],["GILD"],["KDP"],["QCOM"],["GEHC"],["CMCSA"],["ANSS"],["AAPL"],["EA"],["MNST"],["WDAY"],["IDXX"],["TEAM"],["SNPS"],["VRSK"],["AMD"],["CTSH"],["AMAT"],["AXON"],["NFLX"],["DXCM"],["CSGP"],["TSLA"],["DASH"],["CDW"],["BKNG"],["MDLZ"],["CCEP"],["CEG"],["FAST"],["NXPI"],["VRTX"],["PEP"],["CTAS"],["META"],["MAR"],["SHOP"],["MU"],["ADBE"],["PANW"],["ON"],["ROST"],["MELI"],["WBD"],["PAYX"],["KLAC"],["CSX"],["KHC"],["LULU"],["CRWD"],["AZN"],["TXN"],["TTWO"],["ROP"],["ZS"],["GFS"],["ISRG"],["PLTR"],["ADSK"],["CPRT"],["AMGN"],["EXC"],["DDOG"],["AEP"],["PCAR"],["TMUS"],["COST"],["INTU"],["ASML"]],"hovertemplate":"Metric=%{x}\u003cbr\u003eValue=%{y}\u003cbr\u003eTicker=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"RMSE","marker":{"color":"#636efa"},"name":"RMSE","offsetgroup":"RMSE","orientation":"v","points":"all","scalegroup":"True","showlegend":true,"x":["RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE"],"x0":" ","xaxis":"x","y":[0.14117837,0.020343238,0.029267976,0.013220997,0.07353764,0.019327717,0.029032573,0.048669253,0.028577603,0.020134605,0.022527648,0.010317461,0.024787359,0.023840645,0.040318742,0.036756672,0.06345909,0.019190544,0.011578765,0.01581975,0.021845164,0.050893277,0.037025865,0.023718249,0.051679127,0.019157093,0.01444478,0.05179526,0.030447017,0.017369736,0.027219314,0.028143838,0.018577924,0.021189954,0.025550343,0.022215394,0.016782632,0.016006162,0.018053062,0.04180395,0.018597387,0.023217237,0.037526622,0.031770438,0.025346702,0.012964902,0.032867156,0.016006678,0.027664812,0.08479784,0.02072866,0.045794915,0.021821896,0.040156435,0.03559484,0.019010818,0.020593928,0.01138547,0.04645367,0.041426223,0.01640234,0.023852563,0.025236314,0.020629033,0.015187438,0.02591584,0.04026059,0.03433207,0.037729185,0.037427202,0.034472883,0.030141158,0.02381476,0.037557337,0.035470665,0.01671097,0.041663848,0.05975159,0.013448145,0.04721583,0.031151712,0.015802274,0.035632066,0.01601926,0.048886035,0.032000568,0.038440906,0.019082952,0.04008666,0.01958645,0.018608494,0.04712547,0.011859217,0.066114806,0.02290986,0.017483655,0.012983977,0.017920366,0.021212813,0.032331288],"y0":" ","yaxis":"y","type":"violin"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.44444 ...

# %%
import pandas as pd
import plotly.express as px

# Calcular IQR y filtrar outliers por cada métrica
Q1 = df_long.groupby('Metric')['Value'].transform(lambda x: x.quantile(0.25))
Q3 = df_long.groupby('Metric')['Value'].transform(lambda x: x.quantile(0.75))
IQR = Q3 - Q1

# Mantener solo valores dentro de [Q1 - 1.5*IQR, Q3 + 1.5*IQR]
df_long_no_outliers = df_long[
    (df_long['Value'] >= (Q1 - 1.5 * IQR)) &
    (df_long['Value'] <= (Q3 + 1.5 * IQR))
]

# Graficar
fig = px.violin(df_long_no_outliers,
                x='Metric',
                y='Value',
                box=True,
                points='all',
                color='Metric',
                hover_data=['Ticker'])

fig.update_layout(title='Distribution of Regression Metric across Tickers (No Outliers)',
                  yaxis_title='Value',
                  xaxis_title='Metric',
                  legend_title='Metric',
                  width=900,
                  height=500)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4666c167-ddd5-45fa-8ec0-284439cef57c" class="plotly-graph-div" style="height:500px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4666c167-ddd5-45fa-8ec0-284439cef57c")) {                    Plotly.newPlot(                        "4666c167-ddd5-45fa-8ec0-284439cef57c",                        [{"alignmentgroup":"True","box":{"visible":true},"customdata":[["BKR"],["CDNS"],["CSCO"],["GOOG"],["FTNT"],["NVDA"],["TTD"],["GOOGL"],["ODFL"],["ADP"],["MCHP"],["XEL"],["ABNB"],["ADI"],["APP"],["BIIB"],["LIN"],["ORLY"],["REGN"],["AVGO"],["INTC"],["SBUX"],["PDD"],["AMZN"],["HON"],["MRVL"],["PYPL"],["MSFT"],["CHTR"],["LRCX"],["GILD"],["KDP"],["QCOM"],["GEHC"],["CMCSA"],["ANSS"],["AAPL"],["EA"],["MNST"],["WDAY"],["IDXX"],["TEAM"],["SNPS"],["VRSK"],["AMD"],["CTSH"],["AMAT"],["NFLX"],["DXCM"],["CSGP"],["TSLA"],["DASH"],["CDW"],["BKNG"],["MDLZ"],["CCEP"],["CEG"],["FAST"],["NXPI"],["VRTX"],["PEP"],["CTAS"],["META"],["MAR"],["SHOP"],["MU"],["ADBE"],["PANW"],["ON"],["ROST"],["MELI"],["WBD"],["PAYX"],["KLAC"],["CSX"],["KHC"],["LULU"],["CRWD"],["AZN"],["TXN"],["TTWO"],["ROP"],["ZS"],["GFS"],["ISRG"],["PLTR"],["ADSK"],["CPRT"],["AMGN"],["EXC"],["AEP"],["PCAR"],["TMUS"],["COST"],["INTU"],["ASML"]],"hovertemplate":"Metric=%{x}\u003cbr\u003eValue=%{y}\u003cbr\u003eTicker=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"RMSE","marker":{"color":"#636efa"},"name":"RMSE","offsetgroup":"RMSE","orientation":"v","points":"all","scalegroup":"True","showlegend":true,"x":["RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE"],"x0":" ","xaxis":"x","y":[0.020343238,0.029267976,0.013220997,0.019327717,0.029032573,0.048669253,0.028577603,0.020134605,0.022527648,0.010317461,0.024787359,0.023840645,0.040318742,0.036756672,0.06345909,0.019190544,0.011578765,0.01581975,0.021845164,0.050893277,0.037025865,0.023718249,0.051679127,0.019157093,0.01444478,0.05179526,0.030447017,0.017369736,0.027219314,0.028143838,0.018577924,0.021189954,0.025550343,0.022215394,0.016782632,0.016006162,0.018053062,0.04180395,0.018597387,0.023217237,0.037526622,0.031770438,0.025346702,0.012964902,0.032867156,0.016006678,0.027664812,0.02072866,0.045794915,0.021821896,0.040156435,0.03559484,0.019010818,0.020593928,0.01138547,0.04645367,0.041426223,0.01640234,0.023852563,0.025236314,0.020629033,0.015187438,0.02591584,0.04026059,0.03433207,0.037729185,0.037427202,0.034472883,0.030141158,0.02381476,0.037557337,0.035470665,0.01671097,0.041663848,0.05975159,0.013448145,0.04721583,0.031151712,0.015802274,0.035632066,0.01601926,0.048886035,0.032000568,0.038440906,0.019082952,0.04008666,0.01958645,0.018608494,0.04712547,0.011859217,0.02290986,0.017483655,0.012983977,0.017920366,0.021212813,0.032331288],"y0":" ","yaxis":"y","type":"violin"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb ...

# %%
summary_rows = []

metrics = ["Accuracy", "Precision", "Recall", "F1-Score", "RMSE"]

for metric in metrics:
    max_row = results_df.loc[results_df[metric].idxmax(), ["Ticker", metric]]
    min_row = results_df.loc[results_df[metric].idxmin(), ["Ticker", metric]]

    summary_rows.append({
        "Metric": metric,
        "Max_Ticker": max_row["Ticker"],
        "Max_Value": max_row[metric],
        "Min_Ticker": min_row["Ticker"],
        "Min_Value": min_row[metric]
    })

summary_df = pd.DataFrame(summary_rows)

# Formatear a 6 decimales si quieres verlo más limpio
summary_df["Max_Value"] = summary_df["Max_Value"].round(6)
summary_df["Min_Value"] = summary_df["Min_Value"].round(6)

print(summary_df)
# Out:
#       Metric Max_Ticker  Max_Value Min_Ticker  Min_Value
# 0   Accuracy       KLAC   0.702811       VRTX   0.349398
# 1  Precision       KLAC   0.754545       ROST   0.343137
# 2     Recall       ISRG   0.682540       ROST   0.289256
# 3   F1-Score       NXPI   0.692607       ROST   0.313901
# 4       RMSE       FANG   0.141178        ADP   0.010317
