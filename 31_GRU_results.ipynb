# %%
import pandas as pd
results_df = pd.read_csv('gru_evaluation_results.csv')
results_df.head()
# Out:
#   Ticker  Accuracy  Precision    Recall  F1-Score      RMSE
# 0   FANG  0.422131   0.426357  0.450820  0.438247  0.018188
# 1    BKR  0.446721   0.429752  0.440678  0.435146  0.018060
# 2   CDNS  0.540984   0.530769  0.575000  0.552000  0.022079
# 3   CSCO  0.491803   0.470085  0.470085  0.470085  0.011839
# 4   MSTR  0.500000   0.469027  0.460870  0.464912  0.068998

# %%
# Round the results_df.describe in 6 digits
results_df.describe().round(6)
# Out:
#          Accuracy   Precision      Recall    F1-Score        RMSE
# count  101.000000  101.000000  101.000000  101.000000  101.000000
# mean     0.496673    0.491819    0.495038    0.493040    0.023009
# std      0.032724    0.042587    0.043925    0.040876    0.011694
# min      0.422131    0.400000    0.400000    0.410714    0.009660
# 25%      0.475410    0.467213    0.460870    0.466667    0.014467
# 50%      0.495902    0.487603    0.491935    0.491525    0.020373
# 75%      0.520492    0.520000    0.533333    0.528000    0.028592
# max      0.577869    0.619835    0.583333    0.592885    0.076168

# %%
import plotly.express as px

# Suppose your dataframe is called results_df
# Reshape to long format
df_long = pd.melt(results_df, id_vars='Ticker',
                  value_vars=['Accuracy', 'Precision', 'Recall', 'F1-Score'],
                  var_name='Metric', value_name='Value')

# Create violin plot with boxplot and scatter points
fig = px.violin(df_long,
                x='Metric',
                y='Value',
                box=True,          # Add boxplot inside violin
                points='all',      # Show all data points
                color='Metric',    # Different color per metric
                hover_data=['Ticker'])

fig.update_layout(title='Distribution of Classification Metrics across Tickers',
                  yaxis_title='Value',
                  xaxis_title='Metric',
                  legend_title='Metric',
                  width=900,
                  height=500)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="2cfbf35a-1af1-43b8-8539-24f0959fcf78" class="plotly-graph-div" style="height:500px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2cfbf35a-1af1-43b8-8539-24f0959fcf78")) {                    Plotly.newPlot(                        "2cfbf35a-1af1-43b8-8539-24f0959fcf78",                        [{"alignmentgroup":"True","box":{"visible":true},"customdata":[["FANG"],["BKR"],["CDNS"],["CSCO"],["MSTR"],["GOOG"],["FTNT"],["NVDA"],["TTD"],["GOOGL"],["ODFL"],["ADP"],["MCHP"],["XEL"],["ABNB"],["ADI"],["APP"],["BIIB"],["ARM"],["LIN"],["ORLY"],["REGN"],["AVGO"],["INTC"],["SBUX"],["PDD"],["AMZN"],["HON"],["MRVL"],["PYPL"],["MSFT"],["CHTR"],["LRCX"],["GILD"],["KDP"],["QCOM"],["GEHC"],["CMCSA"],["ANSS"],["AAPL"],["EA"],["MNST"],["WDAY"],["IDXX"],["TEAM"],["SNPS"],["VRSK"],["AMD"],["CTSH"],["AMAT"],["AXON"],["NFLX"],["DXCM"],["CSGP"],["TSLA"],["DASH"],["CDW"],["BKNG"],["MDLZ"],["CCEP"],["CEG"],["FAST"],["NXPI"],["VRTX"],["PEP"],["CTAS"],["META"],["MAR"],["SHOP"],["MU"],["ADBE"],["PANW"],["ON"],["ROST"],["MELI"],["WBD"],["PAYX"],["KLAC"],["CSX"],["KHC"],["LULU"],["CRWD"],["AZN"],["TXN"],["TTWO"],["ROP"],["ZS"],["GFS"],["ISRG"],["PLTR"],["ADSK"],["CPRT"],["AMGN"],["EXC"],["DDOG"],["AEP"],["PCAR"],["TMUS"],["COST"],["INTU"],["ASML"]],"hovertemplate":"Metric=%{x}\u003cbr\u003eValue=%{y}\u003cbr\u003eTicker=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Accuracy","marker":{"color":"#636efa"},"name":"Accuracy","offsetgroup":"Accuracy","orientation":"v","points":"all","scalegroup":"True","showlegend":true,"x":["Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy"],"x0":" ","xaxis":"x","y":[0.4221311475409836,0.4467213114754098,0.5409836065573771,0.4918032786885246,0.5,0.5040983606557377,0.5245901639344263,0.4959016393442623,0.5450819672131147,0.4795081967213114,0.5491803278688525,0.4590163934426229,0.4754098360655737,0.4221311475409836,0.4426229508196721,0.5040983606557377,0.5245901639344263,0.4877049180327868,0.5778688524590164,0.5081967213114754,0.5163934426229508,0.4631147540983606,0.4713114754098361,0.4754098360655737,0.5081967213114754,0.4877049180327868,0.4795081967213114,0.4590163934426229,0.5573770491803278,0.4549180327868852,0.4508196721311475,0.4467213114754098,0.5,0.5204918032786885,0.430327868852459,0.5245901639344263,0.4713114754098361,0.4836065573770491,0.4836065573770491,0.5163934426229508,0.5409836065573771,0.4754098360655737,0.5450819672131147,0.4959016393442623,0.4795081967213114,0.4754098360655737,0.5204918032786885,0.5163934426229508,0.5081967213114754,0.5122950819672131,0.5122950819672131,0.5409836065573771,0.4590163934426229,0.5204918032786885,0.5163934426229508,0.5327868852459017,0.4959016393442623, ...

# %%
df_long = pd.melt(results_df, id_vars='Ticker',
                  value_vars=['RMSE'],
                  var_name='Metric', value_name='Value')

# Create violin plot with boxplot and scatter points
fig = px.violin(df_long,
                x='Metric',
                y='Value',
                box=True,          # Add boxplot inside violin
                points='all',      # Show all data points
                color='Metric',    # Different color per metric
                hover_data=['Ticker'])

fig.update_layout(title='Distribution of Regression Metric across Tickers',
                  yaxis_title='Value',
                  xaxis_title='Metric',
                  legend_title='Metric',
                  width=900,
                  height=500)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ebb39682-7552-4645-87bf-51c812186012" class="plotly-graph-div" style="height:500px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ebb39682-7552-4645-87bf-51c812186012")) {                    Plotly.newPlot(                        "ebb39682-7552-4645-87bf-51c812186012",                        [{"alignmentgroup":"True","box":{"visible":true},"customdata":[["FANG"],["BKR"],["CDNS"],["CSCO"],["MSTR"],["GOOG"],["FTNT"],["NVDA"],["TTD"],["GOOGL"],["ODFL"],["ADP"],["MCHP"],["XEL"],["ABNB"],["ADI"],["APP"],["BIIB"],["ARM"],["LIN"],["ORLY"],["REGN"],["AVGO"],["INTC"],["SBUX"],["PDD"],["AMZN"],["HON"],["MRVL"],["PYPL"],["MSFT"],["CHTR"],["LRCX"],["GILD"],["KDP"],["QCOM"],["GEHC"],["CMCSA"],["ANSS"],["AAPL"],["EA"],["MNST"],["WDAY"],["IDXX"],["TEAM"],["SNPS"],["VRSK"],["AMD"],["CTSH"],["AMAT"],["AXON"],["NFLX"],["DXCM"],["CSGP"],["TSLA"],["DASH"],["CDW"],["BKNG"],["MDLZ"],["CCEP"],["CEG"],["FAST"],["NXPI"],["VRTX"],["PEP"],["CTAS"],["META"],["MAR"],["SHOP"],["MU"],["ADBE"],["PANW"],["ON"],["ROST"],["MELI"],["WBD"],["PAYX"],["KLAC"],["CSX"],["KHC"],["LULU"],["CRWD"],["AZN"],["TXN"],["TTWO"],["ROP"],["ZS"],["GFS"],["ISRG"],["PLTR"],["ADSK"],["CPRT"],["AMGN"],["EXC"],["DDOG"],["AEP"],["PCAR"],["TMUS"],["COST"],["INTU"],["ASML"]],"hovertemplate":"Metric=%{x}\u003cbr\u003eValue=%{y}\u003cbr\u003eTicker=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"RMSE","marker":{"color":"#636efa"},"name":"RMSE","offsetgroup":"RMSE","orientation":"v","points":"all","scalegroup":"True","showlegend":true,"x":["RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE"],"x0":" ","xaxis":"x","y":[0.0181881574981026,0.0180603379302926,0.0220792906237629,0.0118392531719661,0.0689983504595423,0.0187998593568377,0.0236175513647796,0.0329681151906205,0.0267384617701994,0.0180129470152591,0.0212050094049721,0.0098268668538891,0.0254444032385651,0.0152293494047964,0.0288992116029426,0.0203677846802962,0.0517293660760429,0.0169829374004892,0.0548989285344126,0.0096603046940193,0.0122895266837479,0.0141330802680358,0.0332062596621159,0.0354931252850823,0.0232708644935925,0.0375038199143288,0.0189723310843248,0.0126596221216637,0.035581132444342,0.0237975613124686,0.012739063357288,0.0259459559862267,0.0275253240893107,0.0158374309605998,0.0116743501143328,0.0244714296165611,0.0761680205132094,0.0157932084208324,0.0153870557843,0.0148415937776541,0.0116917238567746,0.0167435206790934,0.0213918159583007,0.017690054111592,0.0301233166432779,0.0238141838480364,0.0123037464113284,0.0303991452512163,0.0139566554475419,0.0273319438234836,0.0272360591617943,0.0208374836439027,0.0412450121789066,0.0188534212639701,0.0394395512391131,0.0228025728713332,0.0203725336507046,0.0243792772824289,0.0110303867727298,0.0108693831034435,0.0376237146680535,0.0152827584350326,0.0227173571025898,0.0157536460484156,0.0111343792413724,0.0143283238783677,0.024148342229356,0.0137216115435961,0.0332750514651007,0.0330595258296511,0.0236136511241435,0.0304708124746023,0.0293585015892937,0.0138271818011665,0.0246450835283988,0.0321548771610905,0.0141875056024198,0.0285924909 ...

# %%
import pandas as pd
import plotly.express as px

# Calcular IQR y filtrar outliers por cada métrica
Q1 = df_long.groupby('Metric')['Value'].transform(lambda x: x.quantile(0.25))
Q3 = df_long.groupby('Metric')['Value'].transform(lambda x: x.quantile(0.75))
IQR = Q3 - Q1

# Mantener solo valores dentro de [Q1 - 1.5*IQR, Q3 + 1.5*IQR]
df_long_no_outliers = df_long[
    (df_long['Value'] >= (Q1 - 1.5 * IQR)) &
    (df_long['Value'] <= (Q3 + 1.5 * IQR))
]

# Graficar
fig = px.violin(df_long_no_outliers,
                x='Metric',
                y='Value',
                box=True,
                points='all',
                color='Metric',
                hover_data=['Ticker'])

fig.update_layout(title='Distribution of Regression Metric across Tickers (No Outliers)',
                  yaxis_title='Value',
                  xaxis_title='Metric',
                  legend_title='Metric',
                  width=900,
                  height=500)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="27c38ce5-897d-4d20-b699-ae9b21bf82c6" class="plotly-graph-div" style="height:500px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("27c38ce5-897d-4d20-b699-ae9b21bf82c6")) {                    Plotly.newPlot(                        "27c38ce5-897d-4d20-b699-ae9b21bf82c6",                        [{"alignmentgroup":"True","box":{"visible":true},"customdata":[["FANG"],["BKR"],["CDNS"],["CSCO"],["GOOG"],["FTNT"],["NVDA"],["TTD"],["GOOGL"],["ODFL"],["ADP"],["MCHP"],["XEL"],["ABNB"],["ADI"],["BIIB"],["LIN"],["ORLY"],["REGN"],["AVGO"],["INTC"],["SBUX"],["PDD"],["AMZN"],["HON"],["MRVL"],["PYPL"],["MSFT"],["CHTR"],["LRCX"],["GILD"],["KDP"],["QCOM"],["CMCSA"],["ANSS"],["AAPL"],["EA"],["MNST"],["WDAY"],["IDXX"],["TEAM"],["SNPS"],["VRSK"],["AMD"],["CTSH"],["AMAT"],["AXON"],["NFLX"],["DXCM"],["CSGP"],["TSLA"],["DASH"],["CDW"],["BKNG"],["MDLZ"],["CCEP"],["CEG"],["FAST"],["NXPI"],["VRTX"],["PEP"],["CTAS"],["META"],["MAR"],["SHOP"],["MU"],["ADBE"],["PANW"],["ON"],["ROST"],["MELI"],["WBD"],["PAYX"],["KLAC"],["CSX"],["KHC"],["LULU"],["CRWD"],["AZN"],["TXN"],["TTWO"],["ROP"],["ZS"],["GFS"],["ISRG"],["PLTR"],["ADSK"],["CPRT"],["AMGN"],["EXC"],["DDOG"],["AEP"],["PCAR"],["TMUS"],["COST"],["INTU"],["ASML"]],"hovertemplate":"Metric=%{x}\u003cbr\u003eValue=%{y}\u003cbr\u003eTicker=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"RMSE","marker":{"color":"#636efa"},"name":"RMSE","offsetgroup":"RMSE","orientation":"v","points":"all","scalegroup":"True","showlegend":true,"x":["RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE"],"x0":" ","xaxis":"x","y":[0.0181881574981026,0.0180603379302926,0.0220792906237629,0.0118392531719661,0.0187998593568377,0.0236175513647796,0.0329681151906205,0.0267384617701994,0.0180129470152591,0.0212050094049721,0.0098268668538891,0.0254444032385651,0.0152293494047964,0.0288992116029426,0.0203677846802962,0.0169829374004892,0.0096603046940193,0.0122895266837479,0.0141330802680358,0.0332062596621159,0.0354931252850823,0.0232708644935925,0.0375038199143288,0.0189723310843248,0.0126596221216637,0.035581132444342,0.0237975613124686,0.012739063357288,0.0259459559862267,0.0275253240893107,0.0158374309605998,0.0116743501143328,0.0244714296165611,0.0157932084208324,0.0153870557843,0.0148415937776541,0.0116917238567746,0.0167435206790934,0.0213918159583007,0.017690054111592,0.0301233166432779,0.0238141838480364,0.0123037464113284,0.0303991452512163,0.0139566554475419,0.0273319438234836,0.0272360591617943,0.0208374836439027,0.0412450121789066,0.0188534212639701,0.0394395512391131,0.0228025728713332,0.0203725336507046,0.0243792772824289,0.0110303867727298,0.0108693831034435,0.0376237146680535,0.0152827584350326,0.0227173571025898,0.0157536460484156,0.0111343792413724,0.0143283238783677,0.024148342229356,0.0137216115435961,0.0332750514651007,0.0330595258296511,0.0236136511241435,0.0304708124746023,0.0293585015892937,0.0138271818011665,0.0246450835283988,0.0321548771610905,0.0141875056024198,0.0285924909104988,0.0137252516680315,0.0127743789945077,0.0250668845969779,0.0300278149843857,0.0137292992474293,0.019440457403929,0.0155702745787386 ...

# %%
summary_rows = []

metrics = ["Accuracy", "Precision", "Recall", "F1-Score", "RMSE"]

for metric in metrics:
    max_row = results_df.loc[results_df[metric].idxmax(), ["Ticker", metric]]
    min_row = results_df.loc[results_df[metric].idxmin(), ["Ticker", metric]]

    summary_rows.append({
        "Metric": metric,
        "Max_Ticker": max_row["Ticker"],
        "Max_Value": max_row[metric],
        "Min_Ticker": min_row["Ticker"],
        "Min_Value": min_row[metric]
    })

summary_df = pd.DataFrame(summary_rows)

# Formatear a 6 decimales si quieres verlo más limpio
summary_df["Max_Value"] = summary_df["Max_Value"].round(6)
summary_df["Min_Value"] = summary_df["Min_Value"].round(6)

print(summary_df)
# Out:
#       Metric Max_Ticker  Max_Value Min_Ticker  Min_Value
# 0   Accuracy        ARM   0.577869       FANG   0.422131
# 1  Precision        ARM   0.619835        ROP   0.400000
# 2     Recall       CPRT   0.583333       DXCM   0.400000
# 3   F1-Score        ARM   0.592885        HON   0.410714
# 4       RMSE       GEHC   0.076168        LIN   0.009660
