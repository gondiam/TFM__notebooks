# %%
import pandas as pd
results_df = pd.read_csv('lstm_evaluation_results_sc.csv')
results_df.head()
# Out:
#   Ticker  Accuracy  Precision    Recall  F1-Score        RMSE
# 0   FANG  0.524590   0.578125  0.544118  0.560606   22.037217
# 1    BKR  0.508197   0.512397  0.504065  0.508197    2.252786
# 2   CDNS  0.540984   0.546875  0.564516  0.555556   85.658883
# 3   CSCO  0.540984   0.585366  0.541353  0.562500    1.180957
# 4   MSTR  0.504098   0.508333  0.495935  0.502058  124.394575

# %%
# Round the results_df.describe in 6 digits
results_df.describe().round(6)
# Out:
#          Accuracy   Precision      Recall    F1-Score         RMSE
# count  101.000000  101.000000  101.000000  101.000000   101.000000
# mean     0.500487    0.523010    0.510933    0.516035    48.193376
# std      0.027200    0.039853    0.050250    0.040436   121.576903
# min      0.430328    0.413793    0.388430    0.417391     0.847245
# 25%      0.487705    0.500000    0.474138    0.490119     5.201260
# 50%      0.500000    0.523077    0.516129    0.519685    14.279883
# 75%      0.516393    0.548148    0.544118    0.550523    48.736907
# max      0.569672    0.619048    0.629032    0.601399  1127.861715

# %%
import plotly.express as px

# Suppose your dataframe is called results_df
# Reshape to long format
df_long = pd.melt(results_df, id_vars='Ticker',
                  value_vars=['Accuracy', 'Precision', 'Recall', 'F1-Score'],
                  var_name='Metric', value_name='Value')

# Create violin plot with boxplot and scatter points
fig = px.violin(df_long,
                x='Metric',
                y='Value',
                box=True,          # Add boxplot inside violin
                points='all',      # Show all data points
                color='Metric',    # Different color per metric
                hover_data=['Ticker'])

fig.update_layout(title='Distribution of Classification Metrics across Tickers',
                  yaxis_title='Value',
                  xaxis_title='Metric',
                  legend_title='Metric',
                  width=900,
                  height=500)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c030e0d4-0506-4954-b471-eb1ca60a15f9" class="plotly-graph-div" style="height:500px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c030e0d4-0506-4954-b471-eb1ca60a15f9")) {                    Plotly.newPlot(                        "c030e0d4-0506-4954-b471-eb1ca60a15f9",                        [{"alignmentgroup":"True","box":{"visible":true},"customdata":[["FANG"],["BKR"],["CDNS"],["CSCO"],["MSTR"],["GOOG"],["FTNT"],["NVDA"],["TTD"],["GOOGL"],["ODFL"],["ADP"],["MCHP"],["XEL"],["ABNB"],["ADI"],["APP"],["BIIB"],["ARM"],["LIN"],["ORLY"],["REGN"],["AVGO"],["INTC"],["SBUX"],["PDD"],["AMZN"],["HON"],["MRVL"],["PYPL"],["MSFT"],["CHTR"],["LRCX"],["GILD"],["KDP"],["QCOM"],["GEHC"],["CMCSA"],["ANSS"],["AAPL"],["EA"],["MNST"],["WDAY"],["IDXX"],["TEAM"],["SNPS"],["VRSK"],["AMD"],["CTSH"],["AMAT"],["AXON"],["NFLX"],["DXCM"],["CSGP"],["TSLA"],["DASH"],["CDW"],["BKNG"],["MDLZ"],["CCEP"],["CEG"],["FAST"],["NXPI"],["VRTX"],["PEP"],["CTAS"],["META"],["MAR"],["SHOP"],["MU"],["ADBE"],["PANW"],["ON"],["ROST"],["MELI"],["WBD"],["PAYX"],["KLAC"],["CSX"],["KHC"],["LULU"],["CRWD"],["AZN"],["TXN"],["TTWO"],["ROP"],["ZS"],["GFS"],["ISRG"],["PLTR"],["ADSK"],["CPRT"],["AMGN"],["EXC"],["DDOG"],["AEP"],["PCAR"],["TMUS"],["COST"],["INTU"],["ASML"]],"hovertemplate":"Metric=%{x}\u003cbr\u003eValue=%{y}\u003cbr\u003eTicker=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Accuracy","marker":{"color":"#636efa"},"name":"Accuracy","offsetgroup":"Accuracy","orientation":"v","points":"all","scalegroup":"True","showlegend":true,"x":["Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy","Accuracy"],"x0":" ","xaxis":"x","y":[0.5245901639344263,0.5081967213114754,0.5409836065573771,0.5409836065573771,0.5040983606557377,0.4713114754098361,0.4836065573770491,0.4836065573770491,0.5163934426229508,0.4959016393442623,0.4754098360655737,0.4959016393442623,0.5450819672131147,0.5081967213114754,0.4959016393442623,0.5,0.5163934426229508,0.5163934426229508,0.5040983606557377,0.5491803278688525,0.5204918032786885,0.5122950819672131,0.4754098360655737,0.4959016393442623,0.4508196721311475,0.5040983606557377,0.5,0.4959016393442623,0.4549180327868852,0.5163934426229508,0.4918032786885246,0.5286885245901639,0.5409836065573771,0.5122950819672131,0.5040983606557377,0.5122950819672131,0.5,0.4918032786885246,0.4877049180327868,0.5327868852459017,0.5081967213114754,0.4795081967213114,0.4549180327868852,0.4959016393442623,0.5655737704918032,0.5,0.5081967213114754,0.4590163934426229,0.5450819672131147,0.5081967213114754,0.4877049180327868,0.5,0.4877049180327868,0.4877049180327868,0.4959016393442623,0.4877049180327868,0.4467213114754098,0.5491803278688525,0.4795081967213114,0.4713 ...

# %%
df_long = pd.melt(results_df, id_vars='Ticker',
                  value_vars=['RMSE'],
                  var_name='Metric', value_name='Value')

# Create violin plot with boxplot and scatter points
fig = px.violin(df_long,
                x='Metric',
                y='Value',
                box=True,          # Add boxplot inside violin
                points='all',      # Show all data points
                color='Metric',    # Different color per metric
                hover_data=['Ticker'])

fig.update_layout(title='Distribution of Regression Metric across Tickers',
                  yaxis_title='Value',
                  xaxis_title='Metric',
                  legend_title='Metric',
                  width=900,
                  height=500)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="9164598d-a0dd-4b44-a123-8b71ca69105b" class="plotly-graph-div" style="height:500px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9164598d-a0dd-4b44-a123-8b71ca69105b")) {                    Plotly.newPlot(                        "9164598d-a0dd-4b44-a123-8b71ca69105b",                        [{"alignmentgroup":"True","box":{"visible":true},"customdata":[["FANG"],["BKR"],["CDNS"],["CSCO"],["MSTR"],["GOOG"],["FTNT"],["NVDA"],["TTD"],["GOOGL"],["ODFL"],["ADP"],["MCHP"],["XEL"],["ABNB"],["ADI"],["APP"],["BIIB"],["ARM"],["LIN"],["ORLY"],["REGN"],["AVGO"],["INTC"],["SBUX"],["PDD"],["AMZN"],["HON"],["MRVL"],["PYPL"],["MSFT"],["CHTR"],["LRCX"],["GILD"],["KDP"],["QCOM"],["GEHC"],["CMCSA"],["ANSS"],["AAPL"],["EA"],["MNST"],["WDAY"],["IDXX"],["TEAM"],["SNPS"],["VRSK"],["AMD"],["CTSH"],["AMAT"],["AXON"],["NFLX"],["DXCM"],["CSGP"],["TSLA"],["DASH"],["CDW"],["BKNG"],["MDLZ"],["CCEP"],["CEG"],["FAST"],["NXPI"],["VRTX"],["PEP"],["CTAS"],["META"],["MAR"],["SHOP"],["MU"],["ADBE"],["PANW"],["ON"],["ROST"],["MELI"],["WBD"],["PAYX"],["KLAC"],["CSX"],["KHC"],["LULU"],["CRWD"],["AZN"],["TXN"],["TTWO"],["ROP"],["ZS"],["GFS"],["ISRG"],["PLTR"],["ADSK"],["CPRT"],["AMGN"],["EXC"],["DDOG"],["AEP"],["PCAR"],["TMUS"],["COST"],["INTU"],["ASML"]],"hovertemplate":"Metric=%{x}\u003cbr\u003eValue=%{y}\u003cbr\u003eTicker=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"RMSE","marker":{"color":"#636efa"},"name":"RMSE","offsetgroup":"RMSE","orientation":"v","points":"all","scalegroup":"True","showlegend":true,"x":["RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE"],"x0":" ","xaxis":"x","y":[22.03721722121508,2.252785995519357,85.65888320142172,1.180957106320607,124.394575286462,9.337789218308584,9.463819686312515,80.33867434631391,13.427887071486266,21.148318634724333,9.701860538445043,9.56630411293971,3.898459878570984,2.6393183004266683,7.722930033505953,31.005611426947905,85.40612124805283,23.164022361407696,91.26243181934562,74.4291419721295,15.02790337750776,229.95501847602543,85.55398803275968,2.8178808138328018,3.501750857508783,9.05775663311116,14.10473380146298,5.160413100923655,8.477971167358284,2.8068306484862786,76.78990819222118,22.206138533112263,18.01516154138604,3.104828936507086,0.8587094555197872,14.966257783291818,5.789256222722639,1.1055554490917336,7.311462611457609,29.46544368697586,7.730311154999196,3.21758459973537,10.191818689679884,16.993656513746622,10.692764499609927,127.8976139905558,30.41918670200372,21.07407663794413,1.8568099342809767,43.12062956170522,180.4754928959096,80.79744710734518,6.808337692729276,2.800408928837629,36.47412684781695,7.851524473197901,14.279882784833088,1127.861714897812,3.5102720606104145,10.947106136484347,107.00471118387958,5.251016731436233,21.921243031433363,124.7349064916612,3.3719283501866983,67.16312962667328,158.0552978825122,55.50326432439376,6.880221991889092,19.5025971739825,20.136822655254026,58.74306494542888,5.201259761743422,9.811666554452549,131.40037852644355,1.7388093600946923,3.775999032938502,293.51359378435666,1.0098139805249875,0.8472451201414696,15.896 ...

# %%
import pandas as pd
import plotly.express as px

# Calcular IQR y filtrar outliers por cada métrica
Q1 = df_long.groupby('Metric')['Value'].transform(lambda x: x.quantile(0.25))
Q3 = df_long.groupby('Metric')['Value'].transform(lambda x: x.quantile(0.75))
IQR = Q3 - Q1

# Mantener solo valores dentro de [Q1 - 1.5*IQR, Q3 + 1.5*IQR]
df_long_no_outliers = df_long[
    (df_long['Value'] >= (Q1 - 1.5 * IQR)) &
    (df_long['Value'] <= (Q3 + 1.5 * IQR))
]

# Graficar
fig = px.violin(df_long_no_outliers,
                x='Metric',
                y='Value',
                box=True,
                points='all',
                color='Metric',
                hover_data=['Ticker'])

fig.update_layout(title='Distribution of Regression Metric across Tickers (No Outliers)',
                  yaxis_title='Value',
                  xaxis_title='Metric',
                  legend_title='Metric',
                  width=900,
                  height=500)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="973d3b54-ad6d-4917-8e1b-5a2c9cf2aac0" class="plotly-graph-div" style="height:500px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("973d3b54-ad6d-4917-8e1b-5a2c9cf2aac0")) {                    Plotly.newPlot(                        "973d3b54-ad6d-4917-8e1b-5a2c9cf2aac0",                        [{"alignmentgroup":"True","box":{"visible":true},"customdata":[["FANG"],["BKR"],["CDNS"],["CSCO"],["GOOG"],["FTNT"],["NVDA"],["TTD"],["GOOGL"],["ODFL"],["ADP"],["MCHP"],["XEL"],["ABNB"],["ADI"],["APP"],["BIIB"],["ARM"],["LIN"],["ORLY"],["AVGO"],["INTC"],["SBUX"],["PDD"],["AMZN"],["HON"],["MRVL"],["PYPL"],["MSFT"],["CHTR"],["LRCX"],["GILD"],["KDP"],["QCOM"],["GEHC"],["CMCSA"],["ANSS"],["AAPL"],["EA"],["MNST"],["WDAY"],["IDXX"],["TEAM"],["VRSK"],["AMD"],["CTSH"],["AMAT"],["NFLX"],["DXCM"],["CSGP"],["TSLA"],["DASH"],["CDW"],["MDLZ"],["CCEP"],["CEG"],["FAST"],["NXPI"],["PEP"],["CTAS"],["MAR"],["SHOP"],["MU"],["ADBE"],["PANW"],["ON"],["ROST"],["WBD"],["PAYX"],["CSX"],["KHC"],["LULU"],["CRWD"],["AZN"],["TXN"],["TTWO"],["ROP"],["ZS"],["GFS"],["ISRG"],["PLTR"],["ADSK"],["CPRT"],["AMGN"],["EXC"],["DDOG"],["AEP"],["PCAR"],["TMUS"],["INTU"],["ASML"]],"hovertemplate":"Metric=%{x}\u003cbr\u003eValue=%{y}\u003cbr\u003eTicker=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"RMSE","marker":{"color":"#636efa"},"name":"RMSE","offsetgroup":"RMSE","orientation":"v","points":"all","scalegroup":"True","showlegend":true,"x":["RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE","RMSE"],"x0":" ","xaxis":"x","y":[22.03721722121508,2.252785995519357,85.65888320142172,1.180957106320607,9.337789218308584,9.463819686312515,80.33867434631391,13.427887071486266,21.148318634724333,9.701860538445043,9.56630411293971,3.898459878570984,2.6393183004266683,7.722930033505953,31.005611426947905,85.40612124805283,23.164022361407696,91.26243181934562,74.4291419721295,15.02790337750776,85.55398803275968,2.8178808138328018,3.501750857508783,9.05775663311116,14.10473380146298,5.160413100923655,8.477971167358284,2.8068306484862786,76.78990819222118,22.206138533112263,18.01516154138604,3.104828936507086,0.8587094555197872,14.966257783291818,5.789256222722639,1.1055554490917336,7.311462611457609,29.46544368697586,7.730311154999196,3.21758459973537,10.191818689679884,16.993656513746622,10.692764499609927,30.41918670200372,21.07407663794413,1.8568099342809767,43.12062956170522,80.79744710734518,6.808337692729276,2.800408928837629,36.47412684781695,7.851524473197901,14.279882784833088,3.5102720606104145,10.947106136484347,107.00471118387958,5.251016731436233,21.921243031433363,3.3719283501866983,67.16312962667328,55.50326432439376,6.880221991889092,19.5025971739825,20.136822655254026,58.74306494542888,5.201259761743422,9.811666554452549,1.7388093600946923,3.775999032938502,1.0098139805249875,0.8472451201414696,15.896803655539951,57.58677887335374,3.196495044455672,8.444724705712801,4.044450688506008,48.73690739128549,12.30973732805273,3.5961541759135582,96.2114013275126,14.991631693656554,10.835264834457927,14.592064966322948,26.763130316406723,0.916582519557005,5.83854446929506,1.7574183789239073,31.0613385913371,42.21333200021521,20 ...

# %%
summary_rows = []

metrics = ["Accuracy", "Precision", "Recall", "F1-Score", "RMSE"]

for metric in metrics:
    max_row = results_df.loc[results_df[metric].idxmax(), ["Ticker", metric]]
    min_row = results_df.loc[results_df[metric].idxmin(), ["Ticker", metric]]

    summary_rows.append({
        "Metric": metric,
        "Max_Ticker": max_row["Ticker"],
        "Max_Value": max_row[metric],
        "Min_Ticker": min_row["Ticker"],
        "Min_Value": min_row[metric]
    })

summary_df = pd.DataFrame(summary_rows)

# Formatear a 6 decimales si quieres verlo más limpio
summary_df["Max_Value"] = summary_df["Max_Value"].round(6)
summary_df["Min_Value"] = summary_df["Min_Value"].round(6)

print(summary_df)
# Out:
#       Metric Max_Ticker    Max_Value Min_Ticker  Min_Value
# 0   Accuracy        KHC     0.569672       CTAS   0.430328
# 1  Precision       BKNG     0.619048       SBUX   0.413793
# 2     Recall       AMAT     0.629032       INTC   0.388430
# 3   F1-Score       AAPL     0.601399       SBUX   0.417391
# 4       RMSE       BKNG  1127.861715        KHC   0.847245
